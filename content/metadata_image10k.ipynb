# %% [markdown]
# # 📄 Image10k – Category-Specific Metadata Tables

# %% [markdown]
# ### 🙂 Human Faces – Metadata Overview
#
# This section displays metadata for all images in the **human_face** category. Each row includes the file name, source website, license type, author, and a direct link to the original image. The data was curated to ensure proper attribution and licensing.
#
# ⚠️ **Note:** The table below shows a **preview** of the dataset (first 30 rows). You can access the full metadata and all related files here:
#  [📂 Browse metadata folder on Google Drive](https://drive.google.com/drive/folders/1Jb-1pwU7BdeYofvsWuhd83tVgXCp6fFd?usp=sharing)

# %%
import pandas as pd
from IPython.display import HTML, display

def show_with_scroll(df):
    html = df.to_html(index=False, escape=False)
    return HTML(f'''
    <div style="height: 400px; overflow: auto; border: 1px solid #ccc;">
        {html}
    </div>
    ''')

# Load Excel metadata
df_faces = pd.read_excel("../image10k-dataset/human_face.xlsx")

# Preview: just the first 30 rows
df_preview = df_faces.head(30).copy()

# Optional: shorten long text columns like 'metadata'
if 'metadata' in df_preview.columns:
    df_preview['metadata'] = df_preview['metadata'].astype(str).str.slice(0, 150) + '...'

# Display with scroll
display(show_with_scroll(df_preview))
# Out:
#     <div style="height: 400px; overflow: auto; border: 1px solid #ccc;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>ID</th>
#       <th>name</th>
#       <th>website</th>
#       <th>url</th>
#       <th>online_image_id</th>
#       <th>extension</th>
#       <th>metadata</th>
#       <th>include</th>
#       <th>license_code</th>
#       <th>license</th>
#       <th>author</th>
#       <th>source_url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>adolescent_female_face65.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>4054351936</td>
#       <td>NaN</td>
#       <td>{'photo': {'id': '4054351936', 'secret': 'ac100d8be1', 'server': '2461', 'farm': 3, 'dateuploaded': '1256772370', 'isfavorite': 0, 'license': '6', 'sa...</td>
#       <td>1.0</td>
#       <td>6</td>
#       <td>Attribution-NoDerivs License https://creativecommons.org/licenses/by-nd/2.0/</td>
#       <td>(flickr AJU_photography)</td>
#       <td>https://www.flickr.com/photos/28045310@N08/4054351936/</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>adolescent_female_face86.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>5581121531</td>
#       <td>NaN</td>
#       <td>{'photo': {'id': '5581121531', 'secret': '7063cfeabe', 'server': '5136', 'farm': 6, 'dateuploaded': '1301731393', 'isfavorite': 0, 'license': '6', 'sa...</td>
#       <td>1.0</td>
#       <td>6</td>
#       <td>Attribution-NoDerivs License https://creativecommons.org/licenses/by-nd/2.0/</td>
#       <td>(flickr Matthew Kenwrick)</td>
#       <td>https://www.flickr.com/photos/58847482@N03/5581121531/</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>adolescent_female_face95.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>48753900352_4abaa47b33_b.jpg</td>
#       <td>NaN</td>
#       <td>{'photo': {'id': '48753900352', 'secret': '4abaa47b33', 'server': '65535', 'farm': 66, 'dateuploaded': '1568804253', 'isfavorite': 0, 'license': '0', ...</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>All Rights Reserved</td>
#       <td>Psicologia Italia (flickr psicologia24)</td>
#       <td>https://www.flickr.com/photos/psicologia24/48753900352/</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>adolescent_female_face39.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>736814411</td>
#       <td>NaN</td>
#       <td>{'photo': {'id': '736814411', 'secret': '838b4d21b0', 'server': '1154', 'farm': 2, 'dateuploaded': '1183722482', 'isfavorite': 0, 'license': '4', 'saf...</td>
#       <td>1.0</td>
#       <td>4</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>Kyle Taylor (flickr Kyle Taylor, Dream It. Do It.)</td>
#       <td>https://www.flickr.com/photos/kyletaylor/736814411/</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>adolescent_female_face118.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>29910186726_99653dbfd2.jpg</td>
#       <td>NaN</td>
#       <td>{'photo': {'id': '29910186726', 'secret': '99653dbfd2', 'server': '8087', 'farm': 9, 'dateuploaded': '1474904630', 'isfavorite': 0, 'license': '4', 's...</td>
#       <td>1.0</td>
#       <td>4</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>David Stanley (flickr D-Stanley)</td>
#       <td>https://www.flickr.com/photos/davidstanleytravel/29910186726/</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>adolescent_female_face91.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>4309930448_e4506aed4e_s.jpg</td>
#       <td>NaN</td>
#       <td>{'photo': {'id': '4309930448', 'secret': 'e4506aed4e', 'server': '2708', 'farm': 3, 'dateuploaded': '1264621792', 'isfavorite': 0, 'license': '2', 'sa...</td>
#       <td>1.0</td>
#       <td>2</td>
#       <td>NaN</td>
#       <td>(flickr mollybeee)</td>
#       <td>https://www.flickr.com/photos/28590537@N02/4309930448/</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>adolescent_female_face27.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>375364883_6724617f1a_m.jpg</td>
#       <td>NaN</td>
#       <td>{'photo': {'id': '375364883', 'secret': '6724617f1a', 'server': '171', 'farm': 1, 'dateuploaded': '1170237482', 'isfavorite': 0, 'license': '3', 'safe...</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>Attribution-NonCommercial-NoDerivs License https://creativecommons.org/licenses/by-nc-nd/2.0/</td>
#       <td>Corey (flickr Coreyu)</td>
#       <td>https://www.flickr.com/photos/coreyu/375364883/</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>adolescent_female_face54.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>6224095687_0024191a5b_b.jpg</td>
#       <td>NaN</td>
#       <td>{'photo': {'id': '6224095687', 'secret': 'b344df452b', 'server': '6116', 'farm': 7, 'dateuploaded': '1317493993', 'isfavorite': 0, 'license': '2', 'sa...</td>
#       <td>1.0</td>
#       <td>2</td>
#       <td>Attribution-NonCommercial License https://creativecommons.org/licenses/by-nc/2.0/</td>
#       <td>Rob Weir (flickr Rob Weir)</td>
#       <td>https://www.flickr.com/photos/rcweir/6224095687/</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>adolescent_female_face112.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>47756711181_0c37852c6c_b.jpg</td>
#       <td>NaN</td>
#       <td>{'photo': {'id': '47756711181', 'secret': '0c37852c6c', 'server': '65535', 'farm': 66, 'dateuploaded': '1556799241', 'isfavorite': 0, 'license': '5', ...</td>
#       <td>1.0</td>
#       <td>5</td>
#       <td>Attribution-ShareAlike License https://creativecommons.org/licenses/by-sa/2.0/</td>
#       <td>Rod Waddington (flickr Rod Waddington)</td>
#       <td>https://www.flickr.com/photos/rod_waddington/47756711181/</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>adolescent_female_face148.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>37168534404_df1bfc2d80_z.jpg</td>
#       <td>NaN</td>
#       <td>{'photo': {'id': '37168534404', 'secret': 'df1bfc2d80', 'server': '4481', 'farm': 5, 'dateuploaded': '1508760238', 'isfavorite': 0, 'license': '0', 's...</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>All Rights Reserved</td>
#       <td>Bcra Birmingham (flickr breastcancerresearchaid)</td>
#       <td>https://www.flickr.com/photos/breastcancerresearchaid/37168534404/</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>adolescent_female_face29.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>3073127636</td>
#       <td>NaN</td>
#       <td>{'photo': {'id': '3073127636', 'secret': '0e5a7b7ae3', 'server': '3245', 'farm': 4, 'dateuploaded': '1228096878', 'isfavorite': 0, 'license': '4', 'sa...</td>
#       <td>1.0</td>
#       <td>4</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>(flickr merfam)</td>
#       <td>https://www.flickr.com/photos/merfam/3073127636/</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>adolescent_female_face41.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>5084274285</td>
#       <td>NaN</td>
#       <td>{'photo': {'id': '5084274285', 'secret': 'f26e840241', 'server': '4127', 'farm': 5, 'dateuploaded': '1287176315', 'isfavorite': 0, 'license': '5', 'sa...</td>
#       <td>1.0</td>
#       <td>5</td>
#       <td>Attribution-ShareAlike License https://creativecommons.org/licenses/by-sa/2.0/</td>
#       <td>Niels Mulder (flickr niels-mulder)</td>
#       <td>https://www.flickr.com/photos/niels-mulder/5084274285/</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>adolescent_female_face93.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>27525985111_90c41f6783_s.jpg</td>
#       <td>NaN</td>
#       <td>{'photo': {'id': '27525985111', 'secret': '90c41f6783', 'server': '7286', 'farm': 8, 'dateuploaded': '1465646499', 'isfavorite': 0, 'license': '5'

# %% [markdown]
# ### 🧍 Human Body Parts – Metadata Overview
#
# This section displays metadata for images in the **human_body_parts** category. Each entry includes the filename, license type, source platform, and author information. These images typically depict limbs, torsos, or other anatomical segments, and were annotated with careful attention to attribution and copyright compliance.
#
# ⚠️ **Note:** The table below shows a **preview** of the dataset (first 30 rows). You can access the full metadata and all related files here:
#  [📂 Browse metadata folder on Google Drive](https://drive.google.com/drive/folders/1Jb-1pwU7BdeYofvsWuhd83tVgXCp6fFd?usp=sharing)

# %%
import pandas as pd
from IPython.display import HTML, display

# Simple function to show DataFrame with a vertical scrollbar
def show_with_scroll(df):
    html = df.to_html(index=False, escape=False)
    return HTML(f'''
    <div style="height: 400px; overflow: auto; border: 1px solid #ccc;">
        {html}
    </div>
    ''')

# Load the Excel metadata
df_body = pd.read_excel("../image10k-dataset/human_body_parts.xlsx")

# Preview: show only first 30 rows
df_preview = df_body.head(30).copy()

# Optional: shorten long 'metadata' text for cleaner preview
if 'metadata' in df_preview.columns:
    df_preview['metadata'] = df_preview['metadata'].astype(str).str.slice(0, 150) + '...'

# Display the table
display(show_with_scroll(df_preview))
# Out:
#     <div style="height: 400px; overflow: auto; border: 1px solid #ccc;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>ID</th>
#       <th>name</th>
#       <th>website</th>
#       <th>url</th>
#       <th>online_image_id</th>
#       <th>extension</th>
#       <th>metadata</th>
#       <th>include</th>
#       <th>license_code</th>
#       <th>license</th>
#       <th>author</th>
#       <th>source_url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>nose_human6.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>370309071_b14a52de0e_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '370309071', 'secret': 'b14a52de0e', 'server': '124', 'farm': 1, 'dateuploaded': '1169858145', 'isfavorite': 0, 'license': '4', 'safe...</td>
#       <td>True</td>
#       <td>4.0</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>Travis Rigel Lukas Hornung (flickr Travis Hornung)</td>
#       <td>https://www.flickr.com/photos/awfulshot/370309071/</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>nose_human12.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>309968201_98b16b5548_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '309968201', 'secret': '98b16b5548', 'server': '108', 'farm': 1, 'dateuploaded': '1164856993', 'isfavorite': 0, 'license': '4', 'safe...</td>
#       <td>True</td>
#       <td>4.0</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>Gregg O'Connell (flickr greggoconnell)</td>
#       <td>https://www.flickr.com/photos/greggoconnell/309968201/</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>nose_human7.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>8607562978_0afc81cbf4_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '8607562978', 'secret': 'd8c0a17cb1', 'server': '8119', 'farm': 9, 'dateuploaded': '1364759449', 'isfavorite': 0, 'license': '3', 'sa...</td>
#       <td>True</td>
#       <td>3.0</td>
#       <td>Attribution-NonCommercial-NoDerivs License https://creativecommons.org/licenses/by-nc-nd/2.0/</td>
#       <td>(flickr srsldy)</td>
#       <td>https://www.flickr.com/photos/45282854@N00/8607562978/</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>nose_human5.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>866143187_b27149acc9_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '866143187', 'secret': 'c3b8c1db83', 'server': '1096', 'farm': 2, 'dateuploaded': '1185058761', 'isfavorite': 0, 'license': '3', 'saf...</td>
#       <td>True</td>
#       <td>3.0</td>
#       <td>Attribution-NonCommercial-NoDerivs License https://creativecommons.org/licenses/by-nc-nd/2.0/</td>
#       <td>(flickr Phlogiston)</td>
#       <td>https://www.flickr.com/photos/phlogiston/866143187/</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>nose_human3.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>3693819376_a53f9b80f2_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '3693819376', 'secret': 'bbe17fe527', 'server': '3663', 'farm': 4, 'dateuploaded': '1246872742', 'isfavorite': 0, 'license': '4', 'sa...</td>
#       <td>True</td>
#       <td>4.0</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>Bradley Gordon (flickr bradleygee)</td>
#       <td>https://www.flickr.com/photos/icanchangethisright/3693819376/</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>tooth_human12.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>2218841333_c9599e3270_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '2218841333', 'secret': '58987d5d0c', 'server': '2303', 'farm': 3, 'dateuploaded': '1201299215', 'isfavorite': 0, 'license': '3', 'sa...</td>
#       <td>True</td>
#       <td>3.0</td>
#       <td>Attribution-NonCommercial-NoDerivs License https://creativecommons.org/licenses/by-nc-nd/2.0/</td>
#       <td>Lynne Schreur (flickr *lynne*)</td>
#       <td>https://www.flickr.com/photos/lschreur/2218841333/</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>tooth_human14.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>417422945_e1210dfa14_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '417422945', 'secret': '25ac391d10', 'server': '145', 'farm': 1, 'dateuploaded': '1173616117', 'isfavorite': 0, 'license': '4', 'safe...</td>
#       <td>True</td>
#       <td>4.0</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>dion gillard (flickr diongillard)</td>
#       <td>https://www.flickr.com/photos/diongillard/417422945/</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>tooth_human9.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>911782490_18f67f7688_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '911782490', 'secret': 'd555ac4f65', 'server': '1314', 'farm': 2, 'dateuploaded': '1185506828', 'isfavorite': 0, 'license': '2', 'saf...</td>
#       <td>True</td>
#       <td>2.0</td>
#       <td>Attribution-NonCommercial License https://creativecommons.org/licenses/by-nc/2.0/</td>
#       <td>Sarah Mae (flickr Sarah Mae)</td>
#       <td>https://www.flickr.com/photos/sarahmae/911782490/</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>tooth_human10.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>35414764_c311ba862b_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '35414764', 'secret': 'c311ba862b', 'server': '23', 'farm': 1, 'dateuploaded': '1124480844', 'isfavorite': 0, 'license': '4', 'safety...</td>
#       <td>True</td>
#       <td>4.0</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>Bart Everson (flickr Editor B)</td>
#       <td>https://www.flickr.com/photos/editor/35414764/</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>tooth_human6.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>2820493568_2a5ac9ab6c_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '2820493568', 'secret': '1ff6dd66da', 'server': '3074', 'farm': 4, 'dateuploaded': '1220326784', 'isfavorite': 0, 'license': '3', 'sa...</td>
#       <td>True</td>
#       <td>3.0</td>
#       <td>Attribution-NonCommercial-NoDerivs License https://creativecommons.org/licenses/by-nc-nd/2.0/</td>
#       <td>Melissa Segal (flickr Melissa Segal)</td>
#       <td>https://www.flickr.com/photos/frenchie1108/2820493568/</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>tooth_human5.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>1642487161_ca419c6932_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '1642487161', 'secret': '6dc4fed7de', 'server': '2355', 'farm': 3, 'dateuploaded': '1192838165', 'isfavorite': 0, 'license': '3', 'sa...</td>
#       <td>True</td>
#       <td>3.0</td>
#       <td>Attribution-NonCommercial-NoDerivs License https://creativecommons.org/licenses/by-nc-nd/2.0/</td>
#       <td>Melissa Segal (flickr Melissa Segal)</td>
#       <td>https://www.flickr.com/photos/frenchie1108/1642487161/</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>tooth_human3.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>1434527450_38f8f1b4c1_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '1434527450', 'secret': 'ac62f5409c', 'server': '1146', 'farm': 2, 'dateuploaded': '1190658696', 'isfavorite': 0, 'license': '4', 'sa...</td>
#       <td>True</td>
#       <td>4.0</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>Travis Rigel Lukas Hornung (flickr Travis Hornung)</td>
#       <td>https://www.flickr.com/photos/awfulshot/1434527450/</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>tooth_human7.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>5985140617_2312ef3632_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id':

# %% [markdown]
# ### 🐾 Animal Images – Metadata Overview
#
# This section contains the metadata for all images in the **animal** category. Each row corresponds to one image and includes the file name, source website, license type, author and a direct link to the image.
#
# ⚠️ **Note:** The table below shows a **preview** of the dataset (first 30 rows). You can access the full metadata and all related files here:
#  [📂 Browse metadata folder on Google Drive](https://drive.google.com/drive/folders/1Jb-1pwU7BdeYofvsWuhd83tVgXCp6fFd?usp=sharing)

# %%
import pandas as pd
from IPython.display import HTML, display

# Function to show a scrollable DataFrame preview
def show_with_scroll(df):
    html = df.to_html(index=False, escape=False)
    return HTML(f'''
    <div style="height: 400px; overflow: auto; border: 1px solid #ccc;">
        {html}
    </div>
    ''')

# Load metadata
df_animals = pd.read_excel("../image10k-dataset/animal.xlsx")

# Preview: show only first 30 rows
df_preview = df_animals.head(30).copy()

# Truncate long 'metadata' values
if 'metadata' in df_preview.columns:
    df_preview['metadata'] = df_preview['metadata'].astype(str).str.slice(0, 150) + '...'

# Display preview with scroll
display(show_with_scroll(df_preview))
# Out:
#     <div style="height: 400px; overflow: auto; border: 1px solid #ccc;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>ID</th>
#       <th>name</th>
#       <th>website</th>
#       <th>url</th>
#       <th>online_image_id</th>
#       <th>extension</th>
#       <th>metadata</th>
#       <th>include</th>
#       <th>license_code</th>
#       <th>license</th>
#       <th>author</th>
#       <th>source_url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1004</td>
#       <td>body_anemone_fish01.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>2327001147_b37f7da412_o</td>
#       <td>.jpeg</td>
#       <td>{'photo': {'id': '2327001147', 'secret': '5bcabf1236', 'server': '2035', 'farm': 3, 'dateuploaded': '1205274140', 'isfavorite': 0, 'license': '4', 'sa...</td>
#       <td>True</td>
#       <td>4</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>(flickr srgpicker)</td>
#       <td>https://www.flickr.com/photos/srgblog/2327001147/</td>
#     </tr>
#     <tr>
#       <td>1005</td>
#       <td>body_anemone_fish02.jpg</td>
#       <td>_np_</td>
#       <td>https://www.needpix.com</td>
#       <td>clownfish-1453906_1280</td>
#       <td>.jpg</td>
#       <td>nan...</td>
#       <td>True</td>
#       <td>9</td>
#       <td>Public Domain Dedication (CC0) https://creativecommons.org/publicdomain/zero/1.0/</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>1006</td>
#       <td>body_anemone_fish03.jpg</td>
#       <td>_mp_</td>
#       <td>https://www.maxpixel.net</td>
#       <td>Sea-Fish-Underwater-660821</td>
#       <td>.jpg</td>
#       <td>nan...</td>
#       <td>True</td>
#       <td>9</td>
#       <td>Public Domain Dedication (CC0) https://creativecommons.org/publicdomain/zero/1.0/</td>
#       <td>NaN</td>
#       <td>https://www.maxpixel.net/Sea-Fish-Underwater-660821</td>
#     </tr>
#     <tr>
#       <td>1007</td>
#       <td>body_anemone_fish04.jpg</td>
#       <td>_mp_</td>
#       <td>https://www.maxpixel.net</td>
#       <td>Nemo-Clown-Fish-Clown-Sea-Fish-Orange-1121564</td>
#       <td>.jpg</td>
#       <td>nan...</td>
#       <td>True</td>
#       <td>9</td>
#       <td>Public Domain Dedication (CC0) https://creativecommons.org/publicdomain/zero/1.0/</td>
#       <td>NaN</td>
#       <td>https://www.maxpixel.net/Nemo-Clown-Fish-Clown-Sea-Fish-Orange-1121564</td>
#     </tr>
#     <tr>
#       <td>1008</td>
#       <td>body_anemone_fish05.jpg</td>
#       <td>_w_</td>
#       <td>https://commons.wikimedia.org</td>
#       <td>Anemone_purple_anemonefish</td>
#       <td>.jpg</td>
#       <td>{'continue': {'iistart': '2009-01-01T22:25:57Z', 'continue': '||'}, 'query': {'normalized': [{'from': 'Image:Anemone_purple_anemonefish.jpg', 'to': 'F...</td>
#       <td>True</td>
#       <td>C1</td>
#       <td>CC BY-SA 3.0 https://creativecommons.org/licenses/by-sa/3.0</td>
#       <td>Nhobgood - Nick Hobgood</td>
#       <td>https://commons.wikimedia.org/wiki/File:Anemone_purple_anemonefish.jpg</td>
#     </tr>
#     <tr>
#       <td>1009</td>
#       <td>body_anemone_fish06.jpg</td>
#       <td>_w_</td>
#       <td>https://commons.wikimedia.org</td>
#       <td>Clownfisk</td>
#       <td>.jpg</td>
#       <td>{'continue': {'iistart': '2012-11-01T15:09:34Z', 'continue': '||'}, 'query': {'normalized': [{'from': 'Image:Clownfisk.jpg', 'to': 'File:Clownfisk.jpg...</td>
#       <td>True</td>
#       <td>C1</td>
#       <td>CC BY-SA 3.0 https://creativecommons.org/licenses/by-sa/3.0</td>
#       <td>Esquilo</td>
#       <td>https://commons.wikimedia.org/wiki/File:Clownfisk.jpg</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>body_anemone_fish07.jpg</td>
#       <td>_np_</td>
#       <td>https://www.needpix.com</td>
#       <td>poisson-clown-nemo</td>
#       <td>.jpg</td>
#       <td>nan...</td>
#       <td>True</td>
#       <td>9</td>
#       <td>Public Domain Dedication (CC0) https://creativecommons.org/publicdomain/zero/1.0/</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>1011</td>
#       <td>body_anemone_fish08.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>2814662062_5031b3a8d0_o</td>
#       <td>.jpeg</td>
#       <td>{'photo': {'id': '2814662062', 'secret': '2292af6a23', 'server': '3095', 'farm': 4, 'dateuploaded': '1220200107', 'isfavorite': 0, 'license': '4', 'sa...</td>
#       <td>True</td>
#       <td>4</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>(flickr Fotos_PDX)</td>
#       <td>https://www.flickr.com/photos/rocketboom/2814662062/</td>
#     </tr>
#     <tr>
#       <td>1012</td>
#       <td>body_anemone_fish09.jpg</td>
#       <td>_np_</td>
#       <td>https://www.needpix.com</td>
#       <td>clownfish-1453910_1280</td>
#       <td>.jpg</td>
#       <td>nan...</td>
#       <td>True</td>
#       <td>9</td>
#       <td>Public Domain Dedication (CC0) https://creativecommons.org/publicdomain/zero/1.0/</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>1013</td>
#       <td>body_anemone_fish10.jpg</td>
#       <td>_pxh_</td>
#       <td>https://pxhere.com</td>
#       <td>clownfish_anemonefish_fish_sea_nemo_orange_white_amphiprioninae-942137</td>
#       <td>.jpg</td>
#       <td>nan...</td>
#       <td>True</td>
#       <td>9</td>
#       <td>Public Domain Dedication (CC0) https://creativecommons.org/publicdomain/zero/1.0/</td>
#       <td>NaN</td>
#       <td>https://pxhere.com/en/photo/942137</td>
#     </tr>
#     <tr>
#       <td>1014</td>
#       <td>body_anemone_fish11.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>23833933170_6858f62672_o</td>
#       <td>.jpeg</td>
#       <td>{'photo': {'id': '23833933170', 'secret': '5e7728f93e', 'server': '5766', 'farm': 6, 'dateuploaded': '1451756380', 'isfavorite': 0, 'license': '4', 's...</td>
#       <td>True</td>
#       <td>4</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>Teddy Hartanto (flickr hartantoteddy)</td>
#       <td>https://www.flickr.com/photos/138246062@N08/23833933170/</td>
#     </tr>
#     <tr>
#       <td>1015</td>
#       <td>body_anemone_fish12.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>6274514575_24b056fb89_o</td>
#       <td>.jpeg</td>
#       <td>{'photo': {'id': '6274514575', 'secret': '68f9aa7d06', 'server': '6104', 'farm': 7, 'dateuploaded': '1319420657', 'isfavorite': 0, 'license': '5', 'sa...</td>
#       <td>True</td>
#       <td>5</td>
#       <td>Attribution-ShareAlike License https://creativecommons.org/licenses/by-sa/2.0/</td>
#       <td>(flickr amg1994)</td>
#       <td>https://www.flickr.com/photos/agold94/6274514575/</td>
#     </tr>
#     <tr>
#       <td>1016</td>
#       <td>body_anemone_fish13.jpg</td>
#       <td>_pxh_</td>
#       <td>https://pxhere.com</td>
#       <td>photo-1411742</td>
#       <td>.jpg</td>
#       <td>nan...</td>
#       <td>True</td>
#       <td>9</td>
#       <td>Public Domain Dedication (CC0) https://creativecommons.org/publicdomain/zero/1.0/</td>
#       <td>NaN</td>
#       <td>https://pxhere.com/en/photo/1411742</td>
#     </tr>
#     <tr>
#       <td>1017</td>
#       <td>body_anemone_fish14.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>3384552087_9c4485e528_o</td>
#       <td>.jpeg</td>
#       <td>{'photo': {'id': '3384552087', 'secret': '395b0abca5', 'server': '3615', 'farm': 4, 'dateuploaded': '1237995112', 'isfavorite': 0, 'license': '5', 'sa...</td>
#       <td>True</td>
#       <td>5</td>
#       <td>Attribution-ShareAlike License https://creativecommons.org/licenses/by-sa/2.0/</td>
#       <td>(flickr BrainMaY)</td>
#       <td>https://www.flickr.com/photos/brainmay/3384552087/</td>
#     </tr>
#     <tr>
#       <td>1018</td>
#       <td>body_anemone_fish15.jpg</td>
#       <td>_pa_</td>
#       <td>https://pixabay.com</td>
#       <td>nemo-2611306_960_720</td>
#       <td>.jpg</td>
#       <td>nan...</td>
#       <td>True</td>
#       <td>11</td>
#       <td>Pixabay license https://pixabay.com/service/license/</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <td>1019</td>
#       <td>body_ane

# %% [markdown]
# ### 🧩 Objects – Metadata Overview
#
# This section contains metadata for all images in the **object** category. These images represent a wide variety of man-made and natural objects, each annotated with information such as source, author, license type, and file extension. The data was curated to ensure proper attribution and licensing.
#
# ⚠️ **Note:** The table below shows a **preview** of the dataset (first 30 rows). You can access the full metadata and all related files here:
#  [📂 Browse metadata folder on Google Drive](https://drive.google.com/drive/folders/1Jb-1pwU7BdeYofvsWuhd83tVgXCp6fFd?usp=sharing)

# %%
import pandas as pd
from IPython.display import HTML, display

# Function to show a scrollable DataFrame preview
def show_with_scroll(df):
    html = df.to_html(index=False, escape=False)
    return HTML(f'''
    <div style="height: 400px; overflow: auto; border: 1px solid #ccc;">
        {html}
    </div>
    ''')

# Load metadata
df_objects = pd.read_excel("../image10k-dataset/object.xlsx")

# Preview: show only first 30 rows
df_preview = df_objects.head(30).copy()

# Truncate long 'metadata' text
if 'metadata' in df_preview.columns:
    df_preview['metadata'] = df_preview['metadata'].astype(str).str.slice(0, 150) + '...'

# Display preview with scroll
display(show_with_scroll(df_preview))
# Out:
#     <div style="height: 400px; overflow: auto; border: 1px solid #ccc;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>ID</th>
#       <th>name</th>
#       <th>website</th>
#       <th>url</th>
#       <th>online_image_id</th>
#       <th>extension</th>
#       <th>metadata</th>
#       <th>include</th>
#       <th>license_code</th>
#       <th>license</th>
#       <th>author</th>
#       <th>source_url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3840</td>
#       <td>accordion01.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>1171128273_78d3447963_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '1171128273', 'secret': '9695d9fc52', 'server': '1354', 'farm': 2, 'dateuploaded': '1187536128', 'isfavorite': 0, 'license': '2', 'sa...</td>
#       <td>True</td>
#       <td>2</td>
#       <td>Attribution-NonCommercial License https://creativecommons.org/licenses/by-nc/2.0/</td>
#       <td>(flickr kenficara)</td>
#       <td>https://www.flickr.com/photos/kenf/1171128273/</td>
#     </tr>
#     <tr>
#       <td>3841</td>
#       <td>accordion02.jpg</td>
#       <td>_wp_</td>
#       <td>https://www.wallpaperflare.com</td>
#       <td>watch-timepiece-woman-wearing-wrist-wallpaper-preview</td>
#       <td>.jpg</td>
#       <td>nan...</td>
#       <td>True</td>
#       <td>17</td>
#       <td>https://www.wallpaperflare.com/terms-of-use</td>
#       <td>NaN</td>
#       <td>https://www.wallpaperflare.com/harmonica-music-instrument-play-musical-instrument-keys-wallpaper-gbrim/download/1668x2388</td>
#     </tr>
#     <tr>
#       <td>3842</td>
#       <td>accordion03.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>32120524413_15534669cc_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '32120524413', 'secret': '4730102cd0', 'server': '2088', 'farm': 3, 'dateuploaded': '1488122415', 'isfavorite': 0, 'license': '5', 's...</td>
#       <td>True</td>
#       <td>5</td>
#       <td>Attribution-ShareAlike License https://creativecommons.org/licenses/by-sa/2.0/</td>
#       <td>Dennis Jarvis (flickr archer10 (Dennis))</td>
#       <td>https://www.flickr.com/photos/archer10/32120524413/</td>
#     </tr>
#     <tr>
#       <td>3843</td>
#       <td>accordion04.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>37051441305_a8d74b57de_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '37051441305', 'secret': '2f25b33957', 'server': '4425', 'farm': 5, 'dateuploaded': '1504646803', 'isfavorite': 0, 'license': '4', 's...</td>
#       <td>True</td>
#       <td>4</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>Tim Green (flickr Tim Green aka atoach)</td>
#       <td>https://www.flickr.com/photos/atoach/37051441305/</td>
#     </tr>
#     <tr>
#       <td>3844</td>
#       <td>accordion05.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>7166826630_98dfe79d92_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '7166826630', 'secret': 'b932e54989', 'server': '5239', 'farm': 6, 'dateuploaded': '1336595295', 'isfavorite': 0, 'license': '4', 'sa...</td>
#       <td>True</td>
#       <td>4</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>Joe (flickr redakuma)</td>
#       <td>https://www.flickr.com/photos/51241294@N00/7166826630/</td>
#     </tr>
#     <tr>
#       <td>3845</td>
#       <td>accordion06.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>38510101780_941c8e4cb1_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '38510101780', 'secret': '511891666d', 'server': '4627', 'farm': 5, 'dateuploaded': '1518884540', 'isfavorite': 0, 'license': '3', 's...</td>
#       <td>True</td>
#       <td>3</td>
#       <td>Attribution-NonCommercial-NoDerivs License https://creativecommons.org/licenses/by-nc-nd/2.0/</td>
#       <td>(flickr ckilger)</td>
#       <td>https://www.flickr.com/photos/christophkilger/38510101780/</td>
#     </tr>
#     <tr>
#       <td>3846</td>
#       <td>accordion07.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>38623149574_045c50146c_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '38623149574', 'secret': '40aedd053a', 'server': '4735', 'farm': 5, 'dateuploaded': '1514378860', 'isfavorite': 0, 'license': '5', 's...</td>
#       <td>True</td>
#       <td>5</td>
#       <td>Attribution-ShareAlike License https://creativecommons.org/licenses/by-sa/2.0/</td>
#       <td>Jocelyn Erskine-Kellie (flickr Jocelyn777 Love Europe)</td>
#       <td>https://www.flickr.com/photos/jocelyn777/38623149574/</td>
#     </tr>
#     <tr>
#       <td>3847</td>
#       <td>accordion08.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>42601796885_85115d3e4f_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '42601796885', 'secret': '913bae1f87', 'server': '65535', 'farm': 66, 'dateuploaded': '1532002621', 'isfavorite': 0, 'license': '4', ...</td>
#       <td>True</td>
#       <td>4</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>Chris Fithall (flickr seefit)</td>
#       <td>https://www.flickr.com/photos/chrisfithall/42601796885/</td>
#     </tr>
#     <tr>
#       <td>3848</td>
#       <td>accordion09.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>38136445892_bedc3673c1_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '38136445892', 'secret': 'c1cf782d26', 'server': '4444', 'farm': 5, 'dateuploaded': '1509820262', 'isfavorite': 0, 'license': '2', 's...</td>
#       <td>True</td>
#       <td>2</td>
#       <td>Attribution-NonCommercial License https://creativecommons.org/licenses/by-nc/2.0/</td>
#       <td>Eric Chen (flickr ecwchen)</td>
#       <td>https://www.flickr.com/photos/ecwchen/38136445892/</td>
#     </tr>
#     <tr>
#       <td>3849</td>
#       <td>accordion10.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>44067330161_cd61a13f51_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '44067330161', 'secret': '2730255bb7', 'server': '1820', 'farm': 2, 'dateuploaded': '1534413026', 'isfavorite': 0, 'license': '3', 's...</td>
#       <td>True</td>
#       <td>3</td>
#       <td>Attribution-NonCommercial-NoDerivs License https://creativecommons.org/licenses/by-nc-nd/2.0/</td>
#       <td>Ken Mattison (flickr Ken Mattison)</td>
#       <td>https://www.flickr.com/photos/69421573@N08/44067330161/</td>
#     </tr>
#     <tr>
#       <td>3850</td>
#       <td>accordion11.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>34339520976_2fd3fe7ae8_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '34339520976', 'secret': 'd863ec1496', 'server': '2864', 'farm': 3, 'dateuploaded': '1493646247', 'isfavorite': 0, 'license': '5', 's...</td>
#       <td>True</td>
#       <td>5</td>
#       <td>Attribution-ShareAlike License https://creativecommons.org/licenses/by-sa/2.0/</td>
#       <td>North Charleston (flickr North Charleston)</td>
#       <td>https://www.flickr.com/photos/northcharleston/34339520976/</td>
#     </tr>
#     <tr>
#       <td>3851</td>
#       <td>accordion12.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>27465800376_286be337a3_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '27465800376', 'secret': 'd19bca777a', 'server': '7329', 'farm': 8, 'dateuploaded': '1465566489', 'isfavorite': 0, 'license': '4', 's...</td>
#       <td>True</td>
#       <td>4</td>
#       <td>Attribution License https://creativecommons.org/licenses/by/2.0/</td>
#       <td>Blondinrikard Fröberg (flickr blondinrikard)</td>
#       <td>https://www.flickr.com/photos/blondinrikard/27465800376/</td>
#     </tr>
#     <tr>
#       <td>3852</td>
#       <td>accordion13.jpg</td>
#       <td>_f_</td>
#       <td>https://www.flickr.com/photos</td>
#       <td>36708174981_7bfe44a3a2_o</td>
#       <td>.jpg</td>
#       <td>{'photo': {'id': '36708174981', 'secret': '5fd24a97f4', 'server': '4353', 'farm': 5, 'dateuploaded': '1503865156', '
